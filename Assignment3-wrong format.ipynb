# %% [markdown]
# Assignment 3 answers with wrong format!!

# %%
def answer_one():
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    GDP=pd.read_csv('assets/world_bank.csv')
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    Energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)
    Energy.drop(list(range(17)),inplace=True)
    Energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    Energy=Energy.iloc[:227,:]
    Energy['Country'].replace(to_replace ={'\d':'','\(.*\)':''},regex=True,inplace=True)
    Energy[['Energy Supply','Energy Supply per Capita','% Renewable']]=Energy[['Energy Supply','Energy Supply per Capita','% Renewable']].replace(to_replace ='\D*', value = np.NaN, regex = True)
    Energy.reset_index(drop=True,inplace=True)
    for i in range(227):
        if str(Energy.iloc[i,0]).__contains__('Republic of Korea'):
            Energy.iloc[i,0]='South Korea'
        elif str(Energy.iloc[i,0]).__contains__('United States of America'):
            Energy.iloc[i,0]='United States'
        elif str(Energy.iloc[i,0]).__contains__('United Kingdom of Great Britain and Northern Ireland'):
            Energy.iloc[i,0]='United Kingdom'
        elif str(Energy.iloc[i,0]).__contains__('China, Hong Kong Special Administrative Region'):
            Energy.iloc[i,0]='Hong Kong'   
        else:
            pass
    Energy['Energy Supply']=Energy['Energy Supply']*1000000
    GDP.columns=GDP.iloc[3,:]
    GDP=GDP.iloc[4:,:]
    GDP.reset_index(drop=True,inplace=True)
    for i in range(264):
        if str(GDP.iloc[i,0]).__contains__('Korea, Rep.'):
            GDP.iloc[i,0]='South Korea'
        elif str(GDP.iloc[i,0]).__contains__('Iran, Islamic Rep.'):
            GDP.iloc[i,0]='Iran'
        elif str(GDP.iloc[i,0]).__contains__('Hong Kong SAR, China'):
            GDP.iloc[i,0]='Hong Kong'   
        else:
            pass
    GDP.rename({'Country Name':'Country'},axis=1,inplace=True)
    column_list=GDP.columns
    GDP.drop(column_list[1:50],axis=1,inplace=True)
    ScimEn=ScimEn.iloc[:,:8]
    df=ScimEn.merge(Energy,how='inner')
    df=df.merge(GDP,how='inner')
    df.set_index(df['Country'],inplace=True)
    df=df.iloc[:15,:]
    df.drop('Country',axis=1,inplace=True)
    df.columns=['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
    return df
#     raise NotImplementedError()

# %%
def answer_two():
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    GDP=pd.read_csv('assets/world_bank.csv')
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    Energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)
    Energy.drop(list(range(17)),inplace=True)
    Energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    Energy=Energy.iloc[:227,:]
    Energy['Country'].replace(to_replace ={'\d':'','\(.*\)':''},regex=True,inplace=True)
    Energy[['Energy Supply','Energy Supply per Capita','% Renewable']].replace(to_replace ='\D', value = np.NaN, regex = True,inplace=True)
    Energy.reset_index(drop=True,inplace=True)
    for i in range(227):
        if str(Energy.iloc[i,0]).__contains__('Republic of Korea'):
            Energy.iloc[i,0]='South Korea'
        elif str(Energy.iloc[i,0]).__contains__('United States of America'):
            Energy.iloc[i,0]='United States'
        elif str(Energy.iloc[i,0]).__contains__('United Kingdom of Great Britain and Northern Ireland'):
            Energy.iloc[i,0]='United Kingdom'
        elif str(Energy.iloc[i,0]).__contains__('China, Hong Kong Special Administrative Region'):
            Energy.iloc[i,0]='Hong Kong'   
        else:
            pass
    GDP.columns=GDP.iloc[3,:]
    GDP=GDP.iloc[4:,:]
    GDP.reset_index(drop=True,inplace=True)
    for i in range(264):
        if str(GDP.iloc[i,0]).__contains__('Korea, Rep.'):
            GDP.iloc[i,0]='South Korea'
        elif str(GDP.iloc[i,0]).__contains__('Iran, Islamic Rep.'):
            GDP.iloc[i,0]='Iran'
        elif str(GDP.iloc[i,0]).__contains__('Hong Kong SAR, China'):
            GDP.iloc[i,0]='Hong Kong'   
        else:
            pass
    GDP.rename({'Country Name':'Country'},axis=1,inplace=True)
    column_list=GDP.columns
    GDP.drop(column_list[1:50],axis=1,inplace=True)
    ScimEn=ScimEn.iloc[:,:8]
    df=ScimEn.merge(Energy,how='inner')
    df=df.merge(GDP,how='inner')
    df.set_index(df['Country'],inplace=True)
    df.drop('Country',axis=1,inplace=True)
    df2=ScimEn.merge(Energy,how='outer')
    df2=df2.merge(GDP,how='outer')
    df2.set_index(df2['Country'],inplace=True)
    df2.drop('Country',axis=1,inplace=True)
    result=int(df2.size-df.size)
    return result
#     raise NotImplementedError(

# %%
def answer_three():
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    GDP=pd.read_csv('assets/world_bank.csv')
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    Energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)
    Energy.drop(list(range(17)),inplace=True)
    Energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    Energy=Energy.iloc[:227,:]
    Energy['Country'].replace(to_replace ={'\d':'','\(.*\)':''},regex=True,inplace=True)
    Energy[['Energy Supply','Energy Supply per Capita','% Renewable']].replace(to_replace ='\D', value = np.NaN, regex = True,inplace=True)
    Energy.reset_index(drop=True,inplace=True)
    for i in range(227):
        if str(Energy.iloc[i,0]).__contains__('Republic of Korea'):
            Energy.iloc[i,0]='South Korea'
        elif str(Energy.iloc[i,0]).__contains__('United States of America'):
            Energy.iloc[i,0]='United States'
        elif str(Energy.iloc[i,0]).__contains__('United Kingdom of Great Britain and Northern Ireland'):
            Energy.iloc[i,0]='United Kingdom'
        elif str(Energy.iloc[i,0]).__contains__('China, Hong Kong Special Administrative Region'):
            Energy.iloc[i,0]='Hong Kong'   
        else:
            pass
    Energy['Energy Supply']=Energy['Energy Supply']*1000000
    GDP.columns=GDP.iloc[3,:]
    GDP=GDP.iloc[4:,:]
    GDP.reset_index(drop=True,inplace=True)
    for i in range(264):
        if str(GDP.iloc[i,0]).__contains__('Korea, Rep.'):
            GDP.iloc[i,0]='South Korea'
        elif str(GDP.iloc[i,0]).__contains__('Iran, Islamic Rep.'):
            GDP.iloc[i,0]='Iran'
        elif str(GDP.iloc[i,0]).__contains__('Hong Kong SAR, China'):
            GDP.iloc[i,0]='Hong Kong'   
        else:
            pass
    GDP.rename({'Country Name':'Country'},axis=1,inplace=True)
    column_list=GDP.columns
    GDP.drop(column_list[1:50],axis=1,inplace=True)
    ScimEn=ScimEn.iloc[:,:8]
    df=ScimEn.merge(Energy,how='inner')
    df=df.merge(GDP,how='inner')
    df.set_index(df['Country'],inplace=True)
    df.drop('Country',axis=1,inplace=True)
    df.columns=['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
    del_list=['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    df.drop(del_list,inplace=True,axis=1)
    df['average']=df.mean(axis=1)
    df.sort_values('average',axis=0,ascending=False,inplace=True)
    avgGDP=df['average']
    avgGDP=avgGDP.iloc[:15]
    return avgGDP
#     raise NotImplementedError()

# %%
def answer_four():
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    GDP=pd.read_csv('assets/world_bank.csv')
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    Energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)
    Energy.drop(list(range(17)),inplace=True)
    Energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    Energy=Energy.iloc[:227,:]
    Energy['Country'].replace(to_replace ={'\d':'','\(.*\)':''},regex=True,inplace=True)
    Energy[['Energy Supply','Energy Supply per Capita','% Renewable']]=Energy[['Energy Supply','Energy Supply per Capita','% Renewable']].replace(to_replace ='\D', value = np.NaN, regex = True)
    Energy.reset_index(drop=True,inplace=True)
    for i in range(227):
        if str(Energy.iloc[i,0]).__contains__('Republic of Korea'):
            Energy.iloc[i,0]='South Korea'
        elif str(Energy.iloc[i,0]).__contains__('United States of America'):
            Energy.iloc[i,0]='United States'
        elif str(Energy.iloc[i,0]).__contains__('United Kingdom of Great Britain and Northern Ireland'):
            Energy.iloc[i,0]='United Kingdom'
        elif str(Energy.iloc[i,0]).__contains__('China, Hong Kong Special Administrative Region'):
            Energy.iloc[i,0]='Hong Kong'   
        else:
            pass
    Energy['Energy Supply']=Energy['Energy Supply']*1000000
    GDP.columns=GDP.iloc[3,:]
    GDP=GDP.iloc[4:,:]
    GDP.reset_index(drop=True,inplace=True)
    for i in range(264):
        if str(GDP.iloc[i,0]).__contains__('Korea, Rep.'):
            GDP.iloc[i,0]='South Korea'
        elif str(GDP.iloc[i,0]).__contains__('Iran, Islamic Rep.'):
            GDP.iloc[i,0]='Iran'
        elif str(GDP.iloc[i,0]).__contains__('Hong Kong SAR, China'):
            GDP.iloc[i,0]='Hong Kong'   
        else:
            pass
    GDP.rename({'Country Name':'Country'},axis=1,inplace=True)
    column_list=GDP.columns
    GDP.drop(column_list[1:50],axis=1,inplace=True)
    ScimEn=ScimEn.iloc[:,:8]
    df=ScimEn.merge(Energy,how='inner')
    df=df.merge(GDP,how='inner')
    df.set_index(df['Country'],inplace=True)
    df.drop('Country',axis=1,inplace=True)
    df.columns=['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
    del_list=['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    df.drop(del_list,inplace=True,axis=1)
    df['average']=df.mean(axis=1)
    df.sort_values('average',axis=0,ascending=False,inplace=True)
    ser=df.iloc[6,:]
    ser.drop('average',inplace=True)
    result=ser[-1]-ser[1]
    return result

# %%
def answer_five():
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    GDP=pd.read_csv('assets/world_bank.csv')
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    Energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)
    Energy.drop(list(range(17)),inplace=True)
    Energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    Energy=Energy.iloc[:227,:]
    Energy['Country'].replace(to_replace ={'\d':'','\(.*\)':''},regex=True,inplace=True)
    Energy[['Energy Supply','Energy Supply per Capita','% Renewable']]=Energy[['Energy Supply','Energy Supply per Capita','% Renewable']].replace(to_replace ='\D', value = np.NaN, regex = True)
    Energy.reset_index(drop=True,inplace=True)
    for i in range(227):
        if str(Energy.iloc[i,0]).__contains__('Republic of Korea'):
            Energy.iloc[i,0]='South Korea'
        elif str(Energy.iloc[i,0]).__contains__('United States of America'):
            Energy.iloc[i,0]='United States'
        elif str(Energy.iloc[i,0]).__contains__('United Kingdom of Great Britain and Northern Ireland'):
            Energy.iloc[i,0]='United Kingdom'
        elif str(Energy.iloc[i,0]).__contains__('China, Hong Kong Special Administrative Region'):
            Energy.iloc[i,0]='Hong Kong'   
        else:
            pass
    Energy['Energy Supply']=Energy['Energy Supply']*1000000
    GDP.columns=GDP.iloc[3,:]
    GDP=GDP.iloc[4:,:]
    GDP.reset_index(drop=True,inplace=True)
    for i in range(264):
        if str(GDP.iloc[i,0]).__contains__('Korea, Rep.'):
            GDP.iloc[i,0]='South Korea'
        elif str(GDP.iloc[i,0]).__contains__('Iran, Islamic Rep.'):
            GDP.iloc[i,0]='Iran'
        elif str(GDP.iloc[i,0]).__contains__('Hong Kong SAR, China'):
            GDP.iloc[i,0]='Hong Kong'   
        else:
            pass
    GDP.rename({'Country Name':'Country'},axis=1,inplace=True)
    column_list=GDP.columns
    GDP.drop(column_list[1:50],axis=1,inplace=True)
    ScimEn=ScimEn.iloc[:,:8]
    df=ScimEn.merge(Energy,how='inner')
    df=df.merge(GDP,how='inner')
    df.set_index(df['Country'],inplace=True)
    df.drop('Country',axis=1,inplace=True)
    df.columns=['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
    ser=df['Energy Supply per Capita']
    ser[154]=np.NaN
    result=ser.mean()
    return result

# %%
def answer_six():
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    GDP=pd.read_csv('assets/world_bank.csv')
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    Energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)
    Energy.drop(list(range(17)),inplace=True)
    Energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    Energy=Energy.iloc[:227,:]
    Energy['Country'].replace(to_replace ={'\d':'','\(.*\)':''},regex=True,inplace=True)
    Energy[['Energy Supply','Energy Supply per Capita','% Renewable']].replace(to_replace ='\D', value = np.NaN, regex = True,inplace=True)
    Energy.reset_index(drop=True,inplace=True)
    for i in range(227):
        if str(Energy.iloc[i,0]).__contains__('Republic of Korea'):
            Energy.iloc[i,0]='South Korea'
        elif str(Energy.iloc[i,0]).__contains__('United States of America'):
            Energy.iloc[i,0]='United States'
        elif str(Energy.iloc[i,0]).__contains__('United Kingdom of Great Britain and Northern Ireland'):
            Energy.iloc[i,0]='United Kingdom'
        elif str(Energy.iloc[i,0]).__contains__('China, Hong Kong Special Administrative Region'):
            Energy.iloc[i,0]='Hong Kong'   
        else:
            pass
    Energy['Energy Supply']=Energy['Energy Supply']*1000000
    GDP.columns=GDP.iloc[3,:]
    GDP=GDP.iloc[4:,:]
    GDP.reset_index(drop=True,inplace=True)
    for i in range(264):
        if str(GDP.iloc[i,0]).__contains__('Korea, Rep.'):
            GDP.iloc[i,0]='South Korea'
        elif str(GDP.iloc[i,0]).__contains__('Iran, Islamic Rep.'):
            GDP.iloc[i,0]='Iran'
        elif str(GDP.iloc[i,0]).__contains__('Hong Kong SAR, China'):
            GDP.iloc[i,0]='Hong Kong'   
        else:
            pass
    GDP.rename({'Country Name':'Country'},axis=1,inplace=True)
    column_list=GDP.columns
    GDP.drop(column_list[1:50],axis=1,inplace=True)
    ScimEn=ScimEn.iloc[:,:8]
    df=ScimEn.merge(Energy,how='inner')
    df=df.merge(GDP,how='inner')
    df.set_index(df['Country'],inplace=True)
    df.drop('Country',axis=1,inplace=True)
    df.columns=['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']
    temp=[0,0]
    for i in range(len(df.index)):
        if df.iloc[i,df.columns.get_loc('% Renewable')]==df['% Renewable'].max():
            temp[0]=df.index[i]
            temp[1]=df.iloc[i,df.columns.get_loc('% Renewable')]
    result=tuple(temp)
    return result

# %%
def answer_seven():
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    df=ScimEn[['Country','Self-citations','Citations']]
    df['Ratio']=df['Self-citations']/df['Citations']
    temp=[0,0]
    for i in range(len(df.index)):
        if df.iloc[i,3]==df['Ratio'].max():
            temp[0]=df.iloc[i,0]
            temp[1]=df.iloc[i,2]
    result=tuple(temp)
    return result

# %%
def answer_eight():
    Energy=pd.read_excel('assets/Energy Indicators.xls')
    GDP=pd.read_csv('assets/world_bank.csv')
    ScimEn=pd.read_excel('assets/scimagojr-3.xlsx')
    Energy.drop(['Unnamed: 0','Unnamed: 1'],axis=1,inplace=True)
    Energy.drop(list(range(17)),inplace=True)
    Energy.columns=['Country', 'Energy Supply', 'Energy Supply per Capita', '% Renewable']
    Energy=Energy.iloc[:227,:]
    Energy['Country'].replace(to_replace ={'\d':'','\(.*\)':''},regex=True,inplace=True)
    Energy[['Energy Supply','Energy Supply per Capita','% Renewable']]=Energy[['Energy Supply','Energy Supply per Capita','% Renewable']].replace(to_replace ='\.*', value = np.NaN, regex = True)
    Energy.reset_index(drop=True,inplace=True)
    for i in range(227):
        if str(Energy.iloc[i,0]).__contains__('Republic of Korea'):
            Energy.iloc[i,0]='South Korea'
        elif str(Energy.iloc[i,0]).__contains__('United States of America'):
            Energy.iloc[i,0]='United States'
        elif str(Energy.iloc[i,0]).__contains__('United Kingdom of Great Britain and Northern Ireland'):
            Energy.iloc[i,0]='United Kingdom'
        elif str(Energy.iloc[i,0]).__contains__('China, Hong Kong Special Administrative Region'):
            Energy.iloc[i,0]='Hong Kong'   
        else:
            pass
    Energy['Energy Supply']=Energy['Energy Supply']*1000000
    df=Energy[['Country','Energy Supply','Energy Supply per Capita']]
    df['Estimated Population']=df['Energy Supply']/df['Energy Supply per Capita']
    df.sort_values('Estimated Population',ascending=False,inplace=True)
    result=df.iloc[2,0]
    return result
