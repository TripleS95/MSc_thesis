# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure()
plt.subplot(1,2,1)
linear_data=np.array([1,2,3,4,5,6,7,8])
plt.plot(linear_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
exponential_data=linear_data**2
plt.subplot(1,2,2)
plt.plot(exponential_data,'-o')

# %%
plt.subplot(1,2,1)
plt.plot(exponential_data,'-o')
# Out:
# <ipython-input-4-718abf20427e>:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(1,2,1)

# %%
plt.figure()
ax1=plt.subplot(1,2,1)
plt.plot(linear_data,'-o')
ax2=plt.subplot(1,2,2,sharey=ax1)
plt.plot(exponential_data,'-o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig,((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9))=plt.subplots(3,3,sharex=True,sharey=True)
ax4.plot(linear_data,'-.')
ax5.plot(linear_data**1.2,'-.')
ax6.plot(linear_data**1.5,'-.')
ax2.plot(linear_data*4,'-.')
ax8.plot(exponential_data,'-.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
Y=np.random.normal(0,1,10000)
X=np.random.random(10000)
plt.scatter(X,Y)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
plt.figure()
gspec=gridspec.GridSpec(3,3)
tophist=plt.subplot(gspec[0,1:])
sidhist=plt.subplot(gspec[1:,0])
main=plt.subplot(gspec[1:,1:])
main.scatter(X,Y)
tophist.clear()
sidhist.clear()
tophist.hist(X,bins=100,density=True)
sidhist.hist(Y,bins=100,density=True,orientation='horizontal')
sidhist.invert_xaxis()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.gridspec as gridspec
import matplotlib.animation as animation

# defining maximum number of samples
n=100

# sampling from different distributions
x1=np.random.normal(0,1,n)
x3=np.random.normal(0,3,n)
x2= np.random.gamma(2, 2, n)
x4= np.random.gamma(3, 1, n)

# creating gridspec and subplots
fig=plt.figure(figsize=(7,7))
gspec=gridspec.GridSpec(2,2,figure=fig)
normal1=plt.subplot(gspec[0,0])
gamma22=plt.subplot(gspec[0,1])
normal3=plt.subplot(gspec[1,0])
gamma31=plt.subplot(gspec[1,1])
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)

# adding title and counter to the figure
step_txt = fig.text(0.52, 0.96, "Sampling Different Distributions (n= 0)", ha="center",fontsize=14)
# step_txt = fig.text(0.78, 0.96, "(n= 0)", ha="center",fontsize=14)
# fig.suptitle('Sampling Different Distributions',fontsize=14)

# defining function for animating
def func(curr):
    
# stop condition
    if (curr+1)*2>n:
        a.event_source.stop()   
    plt.cla()
    
# plotting normal distribution with 0 average and standard deviation of 1    
    b1=np.arange(-4,4,0.5)
    normal1.hist(x1[:curr*2],bins=b1,color='black')
    normal1.axis([-4,4,0,35])
    normal1.set_ylabel('Frequency')
    normal1.set_xlabel('Value')
    normal1.set_title('Normal, StD=1',fontsize=10)

# plotting gamma distribution with a shpae of 2 and scale of 2
    b2=np.arange(0,5,0.5)
    gamma22.hist(x2[:curr*2],bins=b2,color='cyan')
    gamma22.axis([0,5,0,35])
    gamma22.set_ylabel('Frequency')
    gamma22.set_xlabel('Value')
    gamma22.set_title('Gamma, Shape=2, Scale=2',fontsize=10)
    
# plotting normal distribution with 0 average and standard deviation of 3  
    b3=np.arange(-10,10,2)
    normal3.hist(x3[:curr*2],bins=b3,color='grey')
    normal3.axis([-10,10,0,35])
    normal3.set_ylabel('Frequency')
    normal3.set_xlabel('Value')   
    normal3.set_title('Normal, StD=3',fontsize=10)

# plotting gamma distribution with a shpae of 3 and scale of 1        
    b4=np.arange(0,5,0.5)
    gamma31.hist(x4[:curr*2],bins=b4,color='skyblue')
    gamma31.axis([0,5,0,35])
    gamma31.set_ylabel('Frequency')
    gamma31.set_xlabel('Value')
    gamma31.set_title('Gamma, Shape=3, Scale=1',fontsize=10)
    step_txt.set_text("Sampling Different Distributions (n= {})".format(curr*2))
    
# running the animation    
a=animation.FuncAnimation(fig,func,interval=75)
# Out:
# <img src="data:image/png;base64,..." width="700">
